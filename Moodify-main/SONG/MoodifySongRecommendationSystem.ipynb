# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv('song.csv')

# %%
data.head()
# Out:
#     Age  Hours per day         Fav genre Exploratory Foreign languages    BPM  \
# 0  18.0            3.0             Latin         Yes               Yes  156.0
# 1  63.0            1.5              Rock         Yes                No  119.0
# 2  18.0            4.0  Video game music          No               Yes  132.0
# 3  61.0            2.5              Jazz         Yes               Yes   84.0
# 4  18.0            4.0               R&B         Yes                No  107.0
#
#   Frequency [Classical] Frequency [Country]  Frequency [EDM] Frequency [Folk]  \
# 0                Rarely               Never           Rarely            Never
# 1             Sometimes               Never            Never           Rarely
# 2                 Never               Never  Very frequently            Never
# 3             Sometimes               Never            Never           Rarely
# 4                 Never               Never           Rarely            Never
#
# ...

# %%
data.shape
# Out:
# (736, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           735 non-null    float64
#  1   Hours per day                 736 non-null    float64
#  2   Fav genre                     736 non-null    object
#  3   Exploratory                   736 non-null    object
#  4   Foreign languages             732 non-null    object
#  5   BPM                           629 non-null    float64
#  6   Frequency [Classical]         736 non-null    object
#  7   Frequency [Country]           736 non-null    object
#  8   Frequency [EDM]               736 non-null    object
#  9   Frequency [Folk]              736 non-null    object
#  10  Frequency [Gospel]            736 non-null    object
#  11  Frequency [Hip hop]           736 non-null    object
# ...

# %%
x=data.drop('Fav genre',axis=1)

# %%
x
# Out:
#       Age  Hours per day Exploratory Foreign languages    BPM  \
# 0    18.0            3.0         Yes               Yes  156.0
# 1    63.0            1.5         Yes                No  119.0
# 2    18.0            4.0          No               Yes  132.0
# 3    61.0            2.5         Yes               Yes   84.0
# 4    18.0            4.0         Yes                No  107.0
# ..    ...            ...         ...               ...    ...
# 731  17.0            2.0         Yes               Yes  120.0
# 732  18.0            1.0         Yes               Yes  160.0
# 733  19.0            6.0         Yes                No  120.0
# 734  19.0            5.0          No                No  170.0
# 735  29.0            2.0         Yes               Yes   98.0
#
#     Frequency [Classical] Frequency [Country]  Frequency [EDM]  \
# 0                  Rarely               Never           Rarely
# 1               Sometimes               Never            Never
# ...

# %%
y=data['Fav genre']

# %%
y.head()
# Out:
# 0               Latin
# 1                Rock
# 2    Video game music
# 3                Jazz
# 4                 R&B
# Name: Fav genre, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (515, 25)

# %%
y_train.shape
# Out:
# (515,)

# %%
x_test.shape
# Out:
# (221, 25)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in x_train.columns:
    x_train[column] = label_encoder.fit_transform(x_train[column])
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(x_train.head())
# Out:
#      Age  Hours per day  Exploratory  Foreign languages  BPM  \
# 270    8             11            1                  0   76
# 459   27              8            1                  1   78
# 90    19             11            1                  0   91
# 277    9              5            0                  1    5
# 642   20              6            0                  1   86
#
#      Frequency [Classical]  Frequency [Country]  Frequency [EDM]  \
# 270                      2                    1                0
# 459                      1                    0                0
# 90                       2                    1                0
# 277                      3                    0                0
# 642                      1                    2                0
#
#      Frequency [Folk]  Frequency [Gospel]  ...  Frequency [Metal]  \
# 270                 0                   0  ...                  3
# 459                 0                   0  ...                  3
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
x_train = pd.DataFrame(data)
numeric_columns = x_train.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = x_train.select_dtypes(include=['object']).columns
original_numeric_values = x_train[numeric_columns].copy()
label_encoder = LabelEncoder()
for column in categorical_columns:
    x_train[column] = label_encoder.fit_transform(x_train[column])
print("Encoded DataFrame:")
print(x_train)
x_train[numeric_columns] = original_numeric_values
print("\nRestored DataFrame:")
print(x_train)
# Out:
# Encoded DataFrame:
#       Age  Hours per day  Fav genre  Exploratory  Foreign languages    BPM  \
# 0    18.0            3.0          8            1                  1  156.0
# 1    63.0            1.5         14            1                  0  119.0
# 2    18.0            4.0         15            0                  1  132.0
# 3    61.0            2.5          6            1                  1   84.0
# 4    18.0            4.0         12            1                  0  107.0
# ..    ...            ...        ...          ...                ...    ...
# 731  17.0            2.0         14            1                  1  120.0
# 732  18.0            1.0         11            1                  1  160.0
# 733  19.0            6.0         13            1                  0  120.0
# 734  19.0            5.0          0            0                  0  170.0
# 735  29.0            2.0          5            1                  1   98.0
#
# ...

# %%
print(x_train.head())
# Out:
#     Age  Hours per day  Fav genre  Exploratory  Foreign languages    BPM  \
# 0  18.0            3.0          8            1                  1  156.0
# 1  63.0            1.5         14            1                  0  119.0
# 2  18.0            4.0         15            0                  1  132.0
# 3  61.0            2.5          6            1                  1   84.0
# 4  18.0            4.0         12            1                  0  107.0
#
#    Frequency [Classical]  Frequency [Country]  Frequency [EDM]  \
# 0                      1                    0                1
# 1                      2                    0                0
# 2                      0                    0                3
# 3                      2                    0                0
# 4                      0                    0                1
#
#    Frequency [Folk]  ...  Frequency [Metal]  Frequency [Pop]  Frequency [R&B]  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier


# Create the training DataFrame
x_train = pd.DataFrame(data)
string_labels = ['Latin', 'Rock', 'Video game music', 'Jazz', 'R&B']
repetitions = len(x_train) // len(string_labels)
remainder = len(x_train) % len(string_labels)
y_train = string_labels * repetitions + string_labels[:remainder]  # Adjust to match length
 # Replace with your actual target values

# Separate numeric and categorical columns
numeric_columns = x_train.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = x_train.select_dtypes(include=['object']).columns

# Initialize LabelEncoder and encode categorical columns
label_encoders = {}
for column in categorical_columns:
    le = LabelEncoder()
    x_train[column] = le.fit_transform(x_train[column])
    label_encoders[column] = le  # Store the encoder for later use

# Fit the Decision Tree model
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

# Prepare input for prediction with string values
new_data = {
    'Age': [18],  # Example numeric input
    'Hours per day': [3],  # Example numeric input
    'Fav genre': ['Latin'],
    'Exploratory': ['Yes'],  # String value to encode
    'Foreign languages': ['Yes'],  # String value to encode
    'BPM':[156],
    'Frequency [Classical]': ['Rarely'],
    'Frequency [Country]': ['Never'],
    'Frequency [EDM]': ['Rarely'],
    'Frequency [Folk]': ['Never'],
    'Frequency [Gospel]': ['Never'],
    'Frequency [Hip hop]': ['Sometimes'],
    'Frequency [Jazz]': ['Never'],
    'Frequency [K pop]': ['Very frequently'],
    'Frequency [Latin]': ['Very frequently'],
    'Frequency [Lofi]': ['Rarely'],
    'Frequency [Metal]': ['Never'],
    'Frequency [Pop]': ['Very frequently'],
    'Frequency [R&B]': ['Sometimes'],
    'Frequency [Rap]': ['Very frequently'],
    'Frequency [Rock]': ['Never'],
    'Frequency [Video game music]': ['Sometimes'],
    'Anxiety': [3],
    'Depression': [0],
    'Insomnia': [1],
    'OCD': [0],
}

# Create DataFrame for the new input
input_df = pd.DataFrame(new_data)

# Encode categorical columns in the input DataFrame
for column in categorical_columns:
    input_df[column] = label_encoders[column].transform(input_df[column])

# Make prediction
prediction = model.predict(input_df)

# %%
# Output the prediction
print("Prediction:", prediction)
# Out:
# Prediction: ['Latin']

# %%
import pickle

# %%
with open('songrec.pkl','wb') as file:
  pickle.dump(model, file)
